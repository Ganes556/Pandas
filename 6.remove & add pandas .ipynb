# %%
people= {"first" : ["agung","kurao","mandako"],
        "last":["dwipa","anas","anas"],
        "email": ["agungdwipa@gmail.com","kuraoanas@gmail.com","mandakoanas@gmail.com"]}

# %%
import pandas as pd
data = pd.DataFrame(people)

# %%
data
# Out:
#      first   last                  email
# 0    agung  dwipa   agungdwipa@gmail.com
# 1    kurao   anas    kuraoanas@gmail.com
# 2  mandako   anas  mandakoanas@gmail.com

# %%
data["full_name"] = data["first"] + " " + data["last"]

# %%
data
# Out:
#      first   last                  email     full_name
# 0    agung  dwipa   agungdwipa@gmail.com   agung dwipa
# 1    kurao   anas    kuraoanas@gmail.com    kurao anas
# 2  mandako   anas  mandakoanas@gmail.com  mandako anas

# %%
data.drop(columns=["first","last"],inplace=True)

# %%
data
# Out:
#                    email     full_name
# 0   agungdwipa@gmail.com   agung dwipa
# 1    kuraoanas@gmail.com    kurao anas
# 2  mandakoanas@gmail.com  mandako anas

# %%
data["full_name"].str.split(" ",expand=True)
# Out:
#          0      1
# 0    agung  dwipa
# 1    kurao   anas
# 2  mandako   anas

# %%
data[["first","last"]] = data["full_name"].str.split(" ",expand=True)

# %%
data
# Out:
#                    email     full_name    first   last
# 0   agungdwipa@gmail.com   agung dwipa    agung  dwipa
# 1    kuraoanas@gmail.com    kurao anas    kurao   anas
# 2  mandakoanas@gmail.com  mandako anas  mandako   anas

# %%
data = data.append({"first":"gugun"},ignore_index=True)

# %%
people= {"first" : ["panji","tugus"],
        "last":["dwila","agus"],
        "email": ["panji@gmail.com","tugus1@gmail.com"]}
data2 = pd.DataFrame(people)

# %%
data.append(data2,ignore_index=True)
# Out:
#                    email     full_name    first   last
# 0   agungdwipa@gmail.com   agung dwipa    agung  dwipa
# 1    kuraoanas@gmail.com    kurao anas    kurao   anas
# 2  mandakoanas@gmail.com  mandako anas  mandako   anas
# 3                    NaN           NaN    gugun    NaN
# 4        panji@gmail.com           NaN    panji  dwila
# 5       tugus1@gmail.com           NaN    tugus   agus

# %%
data = data.append(data2,ignore_index=True)

# %%
data.drop(index=[4,3],inplace=True)

# %%
data
# Out:
#                    email     full_name    first   last
# 0   agungdwipa@gmail.com   agung dwipa    agung  dwipa
# 1    kuraoanas@gmail.com    kurao anas    kurao   anas
# 2  mandakoanas@gmail.com  mandako anas  mandako   anas
# 5       tugus1@gmail.com                  tugus   agus

# %%
filt = data["last"] == "anas"
data.drop(index=data[filt].index)
# Out:
#                   email    full_name  first   last
# 0  agungdwipa@gmail.com  agung dwipa  agung  dwipa

# %%
data
# Out:
#                    email     full_name    first   last
# 0   agungdwipa@gmail.com   agung dwipa    agung  dwipa
# 1    kuraoanas@gmail.com    kurao anas    kurao   anas
# 2  mandakoanas@gmail.com  mandako anas  mandako   anas
