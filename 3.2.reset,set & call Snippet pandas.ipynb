# %%
import pandas as pd

# %%
people = {"first": ["Gede","Gusti","Putu"],
            "last": ["Jaya","Hunji","Dio"],
             "email" : ["gedejaya@gmail.com","gustihunji@gmail.com","putudio@gmail.com"]}

# %%
data = pd.DataFrame(people)

# %%
data
# Out:
#    first   last                 email
# 0   Gede   Jaya    gedejaya@gmail.com
# 1  Gusti  Hunji  gustihunji@gmail.com
# 2   Putu    Dio     putudio@gmail.com

# %%
data.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
data.set_index("email",inplace=True) # change index

# %%
data.loc[["gedejaya@gmail.com","putudio@gmail.com"],["last","first"]]
# Out:
#                     last first
# email
# gedejaya@gmail.com  Jaya  Gede
# putudio@gmail.com    Dio  Putu

# %%
data.reset_index(inplace=True) # reset
data
# Out:
#                   email  index  first   last
# 0    gedejaya@gmail.com      0   Gede   Jaya
# 1  gustihunji@gmail.com      1  Gusti  Hunji
# 2     putudio@gmail.com      2   Putu    Dio
