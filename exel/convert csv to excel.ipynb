# %%
import pandas as pd
import xlwt
import csv

# %%
from openpyxl import Workbook
from openpyxl import load_workbook
from openpyxl.styles import Font, Color, Alignment, Border, Side, colors, PatternFill, NamedStyle

# %%
df = df.style.hide_index()

# %%
wb = load_workbook("data/data1_excel.xlsx",read_only=True)
wb.sheetnames
# Out:
# ['Sheet1']

# %%
for x in sheet.iter_rows(min_row=2,max_row=len(sheet["A"])):
    for row in x:
        row.style = "Rows"
for y in sheet.iter_rows(max_row=1):
    for column in y:
        column.style = "Colunm"
        column.fill = PatternFill(start_color='00FFFF00',fill_type='solid')

# %%
# freeze = "A1"
# sheet_first.freeze_panes = freeze
# workbook.save(filename="data/data_freeze.xlsx")

# %%
sheet_first.auto_filter.ref = sheet_first.dimensions

# %%
###########

# %%
# for row in sheet.iter_cols(min_row=1,max_row=5,max_col=3,values_only=True):
#     print(row)
# for row in sheet.iter_rows(min_row=1,max_row=12,max_col=4,values_only=True):
#     print(row)

# %%
# csv to excel 
# read_file=pd.read_csv(r"C:\Users\62831\Documents\GitHub\Pandas_Exel\data\survey_results_schema.csv")
# read_file.to_excel('data/baru.xlsx',index=None)
