# %%
import pandas as pd
public_df = pd.read_csv("data/survey_results_public.csv",index_col="Respondent")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col="Column")

# %%
pd.set_option("display.max_columns",61)
pd.set_option("display.max_rows",61)

# %%
public_df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
#               CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1            European Euro            EUR   Microsoft SQL Server
# 2           Pound sterling            GBP                    NaN
# 3                      NaN            NaN                    NaN
# 4             Albanian lek            ALL                    NaN
# 5                      NaN            NaN       MySQL;PostgreSQL
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                       MySQL;PostgreSQL;Redis;SQLite
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4           White or of European descent    Man
# 5           White or of European descent    Man
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
# 4           Flex time or a flexible schedule;Office enviro...
# 5                                                         NaN
#
#                            JobSat  \
# Respondent
# 1              Slightly satisfied
# 2               Very dissatisfied
# 3                             NaN
# 4           Slightly dissatisfied
# 5                             NaN
#
#                                                       JobSeek  \
# Respondent
# 1                I am not interested in new job opportunities
# 2                I am not interested in new job opportunities
# 3                                                         NaN
# 4           I’m not actively looking, but I am open to new...
# 5                                                         NaN
#
#               LanguageDesireNextYear        LanguageWorkedWith  \
# Respondent
# 1             C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 2                       Python;Swift          JavaScript;Swift
# 3           Objective-C;Python;Swift  Objective-C;Python;Swift
# 4                                NaN                       NaN
# 5                    Java;Ruby;Scala         HTML/CSS;Ruby;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#                  NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1           Somewhat important                    Fairly important
# 2                          NaN                    Fairly important
# 3                          NaN                                 NaN
# 4                          NaN  Not at all important/not necessary
# 5                          NaN                      Very important
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
#
#            NEWJobHuntResearch       NEWLearn NEWOffTopic NEWOnboardGood  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
# 4                         NaN    Once a year    Not sure            Yes
# 5                         NaN    Once a year          No            NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
# 4                 20 to 99 employees
# 5                                NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                         PlatformWorkedWith                      PurchaseWhat  \
# Respondent
# 1                                  Windows                               NaN
# 2                                      iOS     I have little or no influence
# 3                                      NaN                               NaN
# 4                                      NaN  I have a great deal of influence
# 5           AWS;Docker;Linux;MacOS;Windows                               NaN
#
#                           Sexuality SOAccount           SOComm  \
# Respondent
# 1           Straight / Heterosexual        No   No, not at all
# 2                               NaN       Yes  Yes, definitely
# 3                               NaN       Yes    Yes, somewhat
# 4           Straight / Heterosexual       Yes  Yes, definitely
# 5           Straight / Heterosexual       Yes    Yes, somewhat
#
#                                      SOPartFreq  \
# Respondent
# 1                                           NaN
# 2           Less than once per month or monthly
# 3               A few times per month or weekly
# 4               A few times per month or weekly
# 5           Less than once per month or monthly
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#            WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                    ASP.NET Core  ASP.NET;ASP.NET Core
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
# 5            Django;Ruby on Rails         Ruby on Rails
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
#
#            YearsCodePro
# Respondent
# 1                    27
# 2                     4
# 3                   NaN
# 4                     4
# 5                     8

# %%
filt = public_df["LanguageWorkedWith"].str.contains("Python")

# %%
public_df[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 55                     I am a student who is learning to code       No   NaN
# 380         I am not primarily a developer, but I write co...      Yes  38.0
# 404                    I am a student who is learning to code      Yes  17.0
# 508         I am not primarily a developer, but I write co...      Yes   NaN
# 518                            I am a developer by profession      Yes  27.0
# ...                                                       ...      ...   ...
# 65037                  I am a student who is learning to code       No   NaN
# 65205                          I am a developer by profession      Yes   NaN
# 65528                          I am a developer by profession       No   NaN
# 9725                                                      NaN      Yes  65.0
# 22770                                                     NaN      Yes  29.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# Respondent
# 55                 20      NaN        NaN            NaN  United States
# 380                16   Yearly    92300.0        92300.0  United States
# 404                14      NaN        NaN            NaN          Spain
# 508                13   Yearly   250000.0       250000.0  United States
# 518                26   Weekly     1295.0        48950.0         Canada
# ...               ...      ...        ...            ...            ...
# 65037              27      NaN        NaN            NaN        Nigeria
# 65205             NaN      NaN        NaN            NaN        Nigeria
# 65528              16   Yearly   200000.0       151263.0         Canada
# 9725               16      NaN        NaN            NaN         Canada
# 22770              14      NaN        NaN            NaN          Egypt
#
#                     CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 55                           NaN            NaN                    NaN
# 380         United States dollar            USD                    NaN
# 404                          NaN            NaN                    NaN
# 508         United States dollar            USD     MongoDB;PostgreSQL
# 518              Canadian dollar            CAD                    NaN
# ...                          ...            ...                    ...
# 65037                        NaN            NaN                    NaN
# 65205                        NaN            NaN                    NaN
# 65528            Canadian dollar            CAD                    NaN
# 9725                         NaN            NaN                    NaN
# 22770                        NaN            NaN                  MySQL
#
#            DatabaseWorkedWith                                        DevType  \
# Respondent
# 55                      MySQL                                            NaN
# 380                       NaN                                            NaN
# 404                       NaN                                            NaN
# 508                   MongoDB  Data scientist or machine learning specialist
# 518                       NaN  Data scientist or machine learning specialist
# ...                       ...                                            ...
# 65037                     NaN                       Data or business analyst
# 65205                     NaN                                            NaN
# 65528                     NaN                          Developer, QA or test
# 9725                      NaN                                            NaN
# 22770       PostgreSQL;SQLite                                            NaN
#
#                                                       EdLevel  \
# Respondent
# 55                        Associate degree (A.A., A.S., etc.)
# 380           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 404         Secondary school (e.g. American high school, G...
# 508                Other doctoral degree (Ph.D., Ed.D., etc.)
# 518           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                       ...
# 65037            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65205                                                     NaN
# 65528            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9725          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22770            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                     Employment                     Ethnicity  \
# Respondent
# 55          Not employed, but looking for work   Black or of African descent
# 380                         Employed full-time  White or of European descent
# 404                                    Student        Hispanic or Latino/a/x
# 508                         Employed full-time                           NaN
# 518                         Employed full-time  White or of European descent
# ...                                        ...                           ...
# 65037                       Employed full-time                           NaN
# 65205                                  Student                           NaN
# 65528                       Employed full-time                           NaN
# 9725                                   Retired  White or of European descent
# 22770       Not employed, but looking for work                Middle Eastern
#
#            Gender                                         JobFactors  \
# Respondent
# 55            Man  Industry that I’d be working in;Diversity of t...
# 380           Man  Languages, frameworks, and other technologies ...
# 404           Man  Languages, frameworks, and other technologies ...
# 508           NaN  Remote work options;How widely used or impactf...
# 518           Man  Industry that I’d be working in;Flex time or a...
# ...           ...                                                ...
# 65037         NaN  Office environment or company culture;Opportun...
# 65205         NaN                                                NaN
# 65528         NaN                                                NaN
# 9725          Man                                                NaN
# 22770         Man                                                NaN
#
#                     JobSat                                            JobSeek  \
# Respondent
# 55                     NaN                    I am actively looking for a job
# 380         Very satisfied  I’m not actively looking, but I am open to new...
# 404                    NaN       I am not interested in new job opportunities
# 508         Very satisfied       I am not interested in new job opportunities
# 518         Very satisfied  I’m not actively looking, but I am open to new...
# ...                    ...                                                ...
# 65037                  NaN                    I am actively looking for a job
# 65205                  NaN                                                NaN
# 65528       Very satisfied                                                NaN
# 9725                   NaN                                                NaN
# 22770                  NaN                                                NaN
#
#                                LanguageDesireNextYear LanguageWorkedWith  \
# Respondent
# 55                                   C++;JavaScript;R             Python
# 380                                       Python;Rust             Python
# 404                                        C++;Python             Python
# 508                                            Python             Python
# 518                                            Python             Python
# ...                                               ...                ...
# 65037                                          Python             Python
# 65205                                          Python             Python
# 65528                                     Python;Rust             Python
# 9725                                           Python             Python
# 22770       Bash/Shell/PowerShell;C;Objective-C;R;SQL             Python
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 55                                                        NaN
# 380                                                    Pandas
# 404                                                       NaN
# 508         Apache Spark;Hadoop;Pandas;TensorFlow;Torch/Py...
# 518         Apache Spark;Hadoop;Keras;Pandas;TensorFlow;To...
# ...                                                       ...
# 65037                                                     NaN
# 65205                                                  Pandas
# 65528                                                     NaN
# 9725                    Keras;Pandas;TensorFlow;Torch/PyTorch
# 22770                                                     NaN
#
#                                MiscTechWorkedWith  \
# Respondent
# 55                                            NaN
# 380                                        Pandas
# 404                                           NaN
# 508                                        Pandas
# 518         Keras;Pandas;TensorFlow;Torch/PyTorch
# ...                                           ...
# 65037                                         NaN
# 65205                                         NaN
# 65528                                         NaN
# 9725                                       Pandas
# 22770                     Keras;Pandas;TensorFlow
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 55                                                        NaN
# 380                             Github;Gitlab;Microsoft Teams
# 404                                                    Github
# 508                                                    Github
# 518                                    Confluence;Jira;Github
# ...                                                       ...
# 65037                                                     NaN
# 65205       Github;Gitlab;Google Suite (Docs, Meet, etc);S...
# 65528       Confluence;Jira;Github;Google Suite (Docs, Mee...
# 9725                                                   Github
# 22770                                                     NaN
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 55                                                     Github       NaN
# 380                                                    Github        No
# 404                                                    Github       NaN
# 508         Confluence;Jira;Github;Slack;Google Suite (Doc...       Yes
# 518              Confluence;Jira;Github;Slack;Microsoft Teams  Not sure
# ...                                                       ...       ...
# 65037                                                     NaN       NaN
# 65205                                                     NaN       NaN
# 65528       Confluence;Jira;Github;Google Suite (Docs, Mee...       Yes
# 9725                                                   Github       NaN
# 22770                                                     NaN       NaN
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 55                          NaN                                 NaN
# 380                     Neutral                Critically important
# 404                         NaN                                 NaN
# 508         Extremely important                Critically important
# 518                         NaN                  Somewhat important
# ...                         ...                                 ...
# 65037                       NaN                                 NaN
# 65205                       NaN                                 NaN
# 65528        Not very important                  Somewhat important
# 9725                        NaN  Not at all important/not necessary
# 22770                       NaN                    Fairly important
#
#                                                    NEWJobHunt  \
# Respondent
# 55                                                        NaN
# 380         Curious about other opportunities;Better compe...
# 404                                                       NaN
# 508         Better compensation;Better work/life balance;G...
# 518                                       Better compensation
# ...                                                       ...
# 65037                                                     NaN
# 65205                                                     NaN
# 65528                                                     NaN
# 9725                                                      NaN
# 22770                                                     NaN
#
#                                            NEWJobHuntResearch  \
# Respondent
# 55                                                        NaN
# 380         Read company media, such as employee blogs or ...
# 404                                                       NaN
# 508         Read company media, such as employee blogs or ...
# 518         Company reviews from third party sites (e.g. G...
# ...                                                       ...
# 65037                                                     NaN
# 65205                                                     NaN
# 65528                                                     NaN
# 9725                                                      NaN
# 22770                                                     NaN
#
#                         NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# Respondent
# 55                           NaN         Yes            NaN            No
# 380         Once every few years    Not sure             No            No
# 404         Once every few years         Yes            NaN            No
# 508         Once every few years          No            Yes           Yes
# 518                  Once a year    Not sure            Yes            No
# ...                          ...         ...            ...           ...
# 65037                Once a year         NaN            NaN           NaN
# 65205                        NaN         NaN            NaN           NaN
# 65528       Once every few years    Not sure            Yes            No
# 9725        Once every few years         Yes            NaN           NaN
# 22770              Once a decade    Not sure            NaN           NaN
#
#                                                   NEWOvertime  \
# Respondent
# 55                                                        NaN
# 380         Sometimes: 1-2 days per month but less than we...
# 404                                                       NaN
# 508         Occasionally: 1-2 days per quarter but less th...
# 518                                                     Never
# ...                                                       ...
# 65037                                                     NaN
# 65205                                                     NaN
# 65528       Sometimes: 1-2 days per month but less than we...
# 9725                                                      NaN
# 22770                                                     NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 55                                                        NaN
# 380         Start a free trial;Ask developers I know/work ...
# 404         Start a free trial;Ask developers I know/work ...
# 508                                                       NaN
# 518                                                       NaN
# ...                                                       ...
# 65037                                                     NaN
# 65205       Ask developers I know/work with;Visit develope...
# 65528                                                     NaN
# 9725                                       Start a free trial
# 22770         Visit developer communities like Stack Overflow
#
#                 NEWPurpleLink  \
# Respondent
# 55                        NaN
# 380                    Amused
# 404         Hello, old friend
# 508               Indifferent
# 518                    Amused
# ...                       ...
# 65037                     NaN
# 65205       Hello, old friend
# 65528                  Amused
# 9725                   Amused
# 22770                 Annoyed
#
#                                                    NEWSOSites  \
# Respondent
# 55           Stack Overflow (public Q&A for anyone who codes)
# 380         Stack Overflow (public Q&A for anyone who code...
# 404         Stack Overflow (public Q&A for anyone who code...
# 508         Stack Overflow (public Q&A for anyone who code...
# 518         Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 65037                                                     NaN
# 65205        Stack Overflow (public Q&A for anyone who codes)
# 65528       Stack Overflow (public Q&A for anyone who code...
# 9725         Stack Overflow (public Q&A for anyone who codes)
# 22770       Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 55          Go for a walk or other physical activity;Watch...      Windows
# 380         Call a coworker or friend;Visit Stack Overflow...      Windows
# 404         Play games;Call a coworker or friend;Visit Sta...      Windows
# 508         Call a coworker or friend;Go for a walk or oth...        MacOS
# 518         Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                       ...          ...
# 65037                                                     NaN          NaN
# 65205       Meditate;Visit Stack Overflow;Watch help / tut...      Windows
# 65528       Call a coworker or friend;Do other work and co...  Linux-based
# 9725        Visit Stack Overflow;Go for a walk or other ph...      Windows
# 22770       Visit Stack Overflow;Visit another developer c...      Windows
#
#                              OrgSize         PlatformDesireNextYear  \
# Respondent
# 55                               NaN                            NaN
# 380               20 to 99 employees  Linux;Microsoft Azure;Windows
# 404                              NaN                        Windows
# 508             100 to 499 employees                          Linux
# 518         10,000 or more employees                            NaN
# ...                              ...                            ...
# 65037                            NaN                            NaN
# 65205                            NaN                          MacOS
# 65528       10,000 or more employees                  Linux;Windows
# 9725                             NaN                        Windows
# 22770                            NaN                          Linux
#
#              PlatformWorkedWith                   PurchaseWhat  \
# Respondent
# 55          IBM Cloud or Watson                            NaN
# 380               Linux;Windows          I have some influence
# 404                     Windows                            NaN
# 508                       Linux  I have little or no influence
# 518                         NaN  I have little or no influence
# ...                         ...                            ...
# 65037                       NaN                            NaN
# 65205                   Windows                            NaN
# 65528             Linux;Windows  I have little or no influence
# 9725                    Windows                            NaN
# 22770                   Windows                            NaN
#
#                           Sexuality SOAccount           SOComm  \
# Respondent
# 55          Straight / Heterosexual       Yes          Neutral
# 380         Straight / Heterosexual       Yes  Yes, definitely
# 404         Straight / Heterosexual       Yes    Yes, somewhat
# 508         Straight / Heterosexual       Yes  Yes, definitely
# 518         Straight / Heterosexual       Yes  Yes, definitely
# ...                             ...       ...              ...
# 65037                           NaN       NaN              NaN
# 65205                           NaN       Yes              NaN
# 65528                           NaN        No   No, not at all
# 9725        Straight / Heterosexual       Yes    Yes, somewhat
# 22770       Straight / Heterosexual       Yes   No, not really
#
#                                                    SOPartFreq  \
# Respondent
# 55                            A few times per month or weekly
# 380                                     Daily or almost daily
# 404                                      A few times per week
# 508                                    Multiple times per day
# 518                                     Daily or almost daily
# ...                                                       ...
# 65037                                                     NaN
# 65205       I have never participated in Q&A on Stack Over...
# 65528                                                     NaN
# 9725                      Less than once per month or monthly
# 22770                     Less than once per month or monthly
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 55          A few times per month or weekly                        Easy
# 380                  Multiple times per day  Neither easy nor difficult
# 404                    A few times per week  Neither easy nor difficult
# 508                  Multiple times per day                        Easy
# 518                  Multiple times per day                        Easy
# ...                                     ...                         ...
# 65037                                   NaN                         NaN
# 65205       A few times per month or weekly                         NaN
# 65528       A few times per month or weekly                         NaN
# 9725                 Multiple times per day  Neither easy nor difficult
# 22770                  A few times per week  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 55          Appropriate in length    No
# 380         Appropriate in length    No
# 404                      Too long    No
# 508                      Too long    No
# 518         Appropriate in length    No
# ...                           ...   ...
# 65037                         NaN   NaN
# 65205                         NaN   NaN
# 65528                         NaN   NaN
# 9725        Appropriate in length    No
# 22770       Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 55                                  Mathematics or statistics
# 380         Another engineering discipline (such as civil,...
# 404                                                       NaN
# 508                                 Mathematics or statistics
# 518         Computer science, computer engineering, or sof...
# ...                                                       ...
# 65037       A business discipline (such as accounting, fin...
# 65205                                                     NaN
# 65528       Another engineering discipline (such as civil,...
# 9725        A social science (such as anthropology, psycho...
# 22770       Another engineering discipline (such as civil,...
#
#            WebframeDesireNextYear WebframeWorkedWith  \
# Respondent
# 55                            NaN                NaN
# 380                         Flask                NaN
# 404                           NaN                NaN
# 508                           NaN                NaN
# 518                           NaN                NaN
# ...                           ...                ...
# 65037                         NaN                NaN
# 65205                      Django             Django
# 65528                         NaN                NaN
# 9725                          NaN                NaN
# 22770                       Flask                NaN
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 55           Just as welcome now as I felt last year          NaN         2
# 380            A lot less welcome now than last year         48.0        15
# 404         Somewhat more welcome now than last year          NaN         3
# 508            A lot less welcome now than last year         45.0        37
# 518          Just as welcome now as I felt last year         35.0         1
# ...                                              ...          ...       ...
# 65037                                            NaN          NaN       NaN
# 65205                                            NaN          NaN       NaN
# 65528        Just as welcome now as I felt last year         40.0        10
# 9725         Just as welcome now as I felt last year          NaN        49
# 22770        Just as welcome now as I felt last year          NaN         2
#
#                 YearsCodePro
# Respondent
# 55                       NaN
# 380                        6
# 404                      NaN
# 508                       30
# 518         Less than 1 year
# ...                      ...
# 65037                    NaN
# 65205                    NaN
# 65528                      7
# 9725                     NaN
# 22770                    NaN
#
# [651 rows x 60 columns]
