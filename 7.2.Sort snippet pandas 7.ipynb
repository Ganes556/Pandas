# %%
import pandas as pd

# %%
people = {"first": ["Gede","Gusti","Putu","Feto"],
            "last": ["Jaya","Hunji","Dio","Dio"],
             "email" : ["gedejaya@gmail.com","gustihunji@gmail.com","putudio@gmail.com","Fet@email.com"]}

# %%
data = pd.DataFrame(people)

# %%
data.sort_values(by=["last","first"],ascending=[True,False],inplace=True)
data
# Out:
#    first   last                 email
# 2   Putu    Dio     putudio@gmail.com
# 3   Feto    Dio         Fet@email.com
# 1  Gusti  Hunji  gustihunji@gmail.com
# 0   Gede   Jaya    gedejaya@gmail.com

# %%
data.sort_index()
# Out:
#    first   last                 email
# 0   Gede   Jaya    gedejaya@gmail.com
# 1  Gusti  Hunji  gustihunji@gmail.com
# 2   Putu    Dio     putudio@gmail.com
# 3   Feto    Dio         Fet@email.com

# %%
data["last"].sort_values(ascending=True)
# Out:
# 2      Dio
# 3      Dio
# 1    Hunji
# 0     Jaya
# Name: last, dtype: object
